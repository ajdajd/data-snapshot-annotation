# %%
from dsa.constants import ROOT
from dsa.utils import load_json
import pandas as pd

# %%
res_dir = ROOT / "data/evaluation_output/"
res_files = list(res_dir.glob("report*.json"))
res_files
# Out:
# [PosixPath('/home/ajd/data-snapshot-annotation/data/evaluation_output/report_DocLayout-YOLO-D4LA-Docsynth300K_pretrained.json'),
#  PosixPath('/home/ajd/data-snapshot-annotation/data/evaluation_output/report_tfid-large.json'),
#  PosixPath('/home/ajd/data-snapshot-annotation/data/evaluation_output/report_yolo11.json'),
#  PosixPath('/home/ajd/data-snapshot-annotation/data/evaluation_output/report_yolo26.json'),
#  PosixPath('/home/ajd/data-snapshot-annotation/data/evaluation_output/report_DocLayout-YOLO-DocLayNet-Docsynth300K_pretrained.json'),
#  PosixPath('/home/ajd/data-snapshot-annotation/data/evaluation_output/report_DocLayout-YOLO-DocStructBench.json')]

# %%
thresholds = [
    "0.5",
    # "0.75",
]
classes = [
    "Figure",
    "Table",
]
metrics = [
    "precision",
    "recall",
    "mean_iou",
    "mean_area_precision",
    "mean_area_recall",
]

# %%
cols = []
for r in res_files:
    row = {}
    row["filename"] = r.name

    res = load_json(r)
    for t in thresholds:
        for c in classes:
            for m in metrics:
                row[f"[{c}] {m} @ {t}"] = res["metrics"][t]["per_class"][c][m]

    cols.append(row)

# %%
df = pd.DataFrame(cols).set_index("filename").transpose()
df
# Out:
# filename                            report_DocLayout-YOLO-D4LA-Docsynth300K_pretrained.json  \
# [Figure] precision @ 0.5                                                     0.119403
# [Figure] recall @ 0.5                                                        0.307692
# [Figure] mean_iou @ 0.5                                                      0.898999
# [Figure] mean_area_precision @ 0.5                                           0.998954
# [Figure] mean_area_recall @ 0.5                                              0.900012
# [Table] precision @ 0.5                                                      0.046296
# [Table] recall @ 0.5                                                         0.833333
# [Table] mean_iou @ 0.5                                                       0.836466
# [Table] mean_area_precision @ 0.5                                            0.998776
# [Table] mean_area_recall @ 0.5                                               0.837207
#
# filename                            report_tfid-large.json  \
# [Figure] precision @ 0.5                          0.565217
# [Figure] recall @ 0.5                             0.500000
# [Figure] mean_iou @ 0.5                           0.785874
# [Figure] mean_area_precision @ 0.5                0.831807
# [Figure] mean_area_recall @ 0.5                   0.951672
# [Table] precision @ 0.5                           0.312500
# [Table] recall @ 0.5                              0.833333
# [Table] mean_iou @ 0.5                            0.987176
# [Table] mean_area_precision @ 0.5                 0.987209
# [Table] mean_area_recall @ 0.5                    0.999966
#
# filename                            report_yolo11.json  report_yolo26.json  \
# [Figure] precision @ 0.5                      0.208738            0.222222
# [Figure] recall @ 0.5                         0.826923            0.846154
# [Figure] mean_iou @ 0.5                       0.892653            0.866648
# [Figure] mean_area_precision @ 0.5            0.985033            0.991067
# [Figure] mean_area_recall @ 0.5               0.907246            0.875309
# [Table] precision @ 0.5                       0.230769            0.185185
# [Table] recall @ 0.5                          1.000000            0.833333
# [Table] mean_iou @ 0.5                        0.929578            0.959615
# [Table] mean_area_precision @ 0.5             0.986954            0.999247
# [Table] mean_area_recall @ 0.5                0.940828            0.960318
#
# filename                            report_DocLayout-YOLO-DocLayNet-Docsynth300K_pretrained.json  \
# [Figure] precision @ 0.5                                                     0.244444
# [Figure] recall @ 0.5                                                        0.846154
# [Figure] mean_iou @ 0.5                                                      0.902551
# [Figure] mean_area_precision @ 0.5                                           0.997662
# [Figure] mean_area_recall @ 0.5                                              0.904731
# [Table] precision @ 0.5                                                      0.272727
# [Table] recall @ 0.5                                                         1.000000
# [Table] mean_iou @ 0.5                                                       0.952091
# [Table] mean_area_precision @ 0.5                                            0.998864
# [Table] mean_area_recall @ 0.5                                               0.953213
#
# filename                            report_DocLayout-YOLO-DocStructBench.json
# [Figure] precision @ 0.5                                             0.458333
# [Figure] recall @ 0.5                                                0.846154
# [Figure] mean_iou @ 0.5                                              0.872503
# [Figure] mean_area_precision @ 0.5                                   0.999135
# [Figure] mean_area_recall @ 0.5                                      0.873311
# [Table] precision @ 0.5                                              0.227273
# [Table] recall @ 0.5                                                 0.833333
# [Table] mean_iou @ 0.5                                               0.964728
# [Table] mean_area_precision @ 0.5                                    0.994969
# [Table] mean_area_recall @ 0.5                                       0.969718

# %%
df.to_clipboard()
