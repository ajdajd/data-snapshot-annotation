# %%
import pandas as pd

# df = pd.read_json("data/results_prwp_batch1.jsonl", lines=True)
df = pd.read_json("data/results_refugee_batch1.jsonl", lines=True)
df
# Out:
#                                           snapshot_id  \
# 0        112_IDAR2016-0221-PAD-09012016_table_007.png
# 1   056_Niger-COVID-19-Emergency-Response-Project_...
# 2                       194_multi-page_figure_000.png
# 3   069_Pakistan-Strengthening-Institutions-for-Re...
# 4                        202_multi0page_table_007.png
# 5                        203_multi-page_table_006.png
# 6                        197_multi-page_table_000.png
# 7                        189_multi-page_table_012.png
# 8                        199_multi0page_table_004.png
# 9                       191_multi-page_figure_000.png
# 10  121_PAD1190-PAD-P152848-PUBLIC-Box391435B-LB-E...
# 11                       203_multi-page_table_009.png
# 12  074_Djibouti-Integrated-Cash-Transfer-and-Huma...
# 13  014_BOSIB1dda1d49e0221807413cf06ea9ae3f_table_...
# 14                       193_multi-page_table_010.png
# 15                       194_multi-page_table_000.png
# 16                       191_multi-page_table_006.png
# 17  006_BOSIB-2c22668f-f4ba-42f5-a0d1-7949b7b8fe34...
# 18  004_BOSIB-87c444de-4797-4bf9-b654-4932a7fb0112...
# 19                       202_multi0page_table_008.png
# 20                       191_multi-page_table_000.png
# 21                       200_multi-page_table_014.png
# 22                       193_multi-page_table_007.png
# 23                       193_multi-page_table_006.png
# 24                       199_multi0page_table_001.png
# 25  121_PAD1190-PAD-P152848-PUBLIC-Box391435B-LB-E...
# 26                      189_multi-page_figure_001.png
# 27  091_PAD2604-ARABIC-PUBLIC-Project-Appraisal-Do...
# 28  054_Sudan-Basic-Education-Emergency-Support-Pr...
# 29  004_BOSIB-87c444de-4797-4bf9-b654-4932a7fb0112...
# 30                      193_multi-page_figure_001.png
# 31  005_BOSIB-8191b179-7209-4faa-b5e0-11783bcd492d...
# 32                      203_multi-page_figure_003.png
# 33  040_Iraq-COVID-19-Vaccination-Project_table_00...
# 34  121_PAD1190-PAD-P152848-PUBLIC-Box391435B-LB-E...
#
#                                            image_path source_label  \
# 0   data/refugee_batch1/112_IDAR2016-0221-PAD-0901...      Refugee
# 1   data/refugee_batch1/056_Niger-COVID-19-Emergen...      Refugee
# 2   data/refugee_batch1/194_multi-page_figure_000.png      Refugee
# 3   data/refugee_batch1/069_Pakistan-Strengthening...      Refugee
# 4    data/refugee_batch1/202_multi0page_table_007.png      Refugee
# 5    data/refugee_batch1/203_multi-page_table_006.png      Refugee
# 6    data/refugee_batch1/197_multi-page_table_000.png      Refugee
# 7    data/refugee_batch1/189_multi-page_table_012.png      Refugee
# 8    data/refugee_batch1/199_multi0page_table_004.png      Refugee
# 9   data/refugee_batch1/191_multi-page_figure_000.png      Refugee
# 10  data/refugee_batch1/121_PAD1190-PAD-P152848-PU...      Refugee
# 11   data/refugee_batch1/203_multi-page_table_009.png      Refugee
# 12  data/refugee_batch1/074_Djibouti-Integrated-Ca...      Refugee
# 13  data/refugee_batch1/014_BOSIB1dda1d49e02218074...      Refugee
# 14   data/refugee_batch1/193_multi-page_table_010.png      Refugee
# 15   data/refugee_batch1/194_multi-page_table_000.png      Refugee
# 16   data/refugee_batch1/191_multi-page_table_006.png      Refugee
# 17  data/refugee_batch1/006_BOSIB-2c22668f-f4ba-42...      Refugee
# 18  data/refugee_batch1/004_BOSIB-87c444de-4797-4b...      Refugee
# 19   data/refugee_batch1/202_multi0page_table_008.png      Refugee
# 20   data/refugee_batch1/191_multi-page_table_000.png      Refugee
# 21   data/refugee_batch1/200_multi-page_table_014.png      Refugee
# 22   data/refugee_batch1/193_multi-page_table_007.png      Refugee
# 23   data/refugee_batch1/193_multi-page_table_006.png      Refugee
# 24   data/refugee_batch1/199_multi0page_table_001.png      Refugee
# 25  data/refugee_batch1/121_PAD1190-PAD-P152848-PU...      Refugee
# 26  data/refugee_batch1/189_multi-page_figure_001.png      Refugee
# 27  data/refugee_batch1/091_PAD2604-ARABIC-PUBLIC-...      Refugee
# 28  data/refugee_batch1/054_Sudan-Basic-Education-...      Refugee
# 29  data/refugee_batch1/004_BOSIB-87c444de-4797-4b...      Refugee
# 30  data/refugee_batch1/193_multi-page_figure_001.png      Refugee
# 31  data/refugee_batch1/005_BOSIB-8191b179-7209-4f...      Refugee
# 32  data/refugee_batch1/203_multi-page_figure_003.png      Refugee
# 33  data/refugee_batch1/040_Iraq-COVID-19-Vaccinat...      Refugee
# 34  data/refugee_batch1/121_PAD1190-PAD-P152848-PU...      Refugee
#
#                                            llm_output  \
# 0   {'visible_text_label': 'Consultancy Assignment...
# 1   {'visible_text_label': 'Figure 1: Countries, t...
# 2   {'visible_text_label': 'Annex 10: Country at a...
# 3   {'visible_text_label': 'Project Development Ob...
# 4   {'visible_text_label': 'Annex 6
# El Nino Emerge...
# 5   {'visible_text_label': 'Table C: Allocation of...
# 6   {'visible_text_label': 'Component', 'data_moda...
# 7   {'visible_text_label': 'none', 'data_modality'...
# 8   {'visible_text_label': 'Project Cost and Finan...
# 9   {'visible_text_label': 'Burundi at a glance', ...
# 10  {'visible_text_label': 'Table 3: Procurement o...
# 11  {'visible_text_label': 'Jordan STATEMENT OF IF...
# 12  {'visible_text_label': 'Beneficiaries with acc...
# 13  {'visible_text_label': '1 : FIGA is reformed i...
# 14  {'visible_text_label': 'STATEMENT OF IFC's Com...
# 15  {'visible_text_label': '1. Project components ...
# 16  {'visible_text_label': 'TABLE A: PROJECT COSTS...
# 17  {'visible_text_label': 'Enhanced production an...
# 18  {'visible_text_label': 'IDA Resources (US$, Mi...
# 19  {'visible_text_label': 'Uganda STATEMENT OF IF...
# 20  {'visible_text_label': 'Project Financing Data...
# 21  {'visible_text_label': 'Table C: Allocation of...
# 22  {'visible_text_label': 'Annex 4, Table D: Allo...
# 23  {'visible_text_label': 'Annex 4, Table C: Summ...
# 24  {'visible_text_label': '1. Project components ...
# 25  {'visible_text_label': 'Category
# Amount of the...
# 26  {'visible_text_label': 'PRICES and GOVERNMENT ...
# 27  {'visible_text_label': '4.7 موجز التحليلي (بال...
# 28  {'visible_text_label': 'Team', 'data_modality'...
# 29  {'visible_text_label': 'PDO Indicators by PDO ...
# 30  {'visible_text_label': 'Tajikistan', 'data_mod...
# 31  {'visible_text_label': 'Microcredentials firm ...
# 32  {'visible_text_label': 'JORDAN COMMUNITY INFRA...
# 33  {'visible_text_label': 'Table 5: Project Cost ...
# 34  {'visible_text_label': 'Table 1: Implementatio...
#
#                                            raw_output  \
# 0   ```json\n{\n  "visible_text_label": "Consultan...
# 1   {\n  "visible_text_label": "Figure 1: Countrie...
# 2   ```json\n{\n  "visible_text_label": "Annex 10:...
# 3   {\n  "visible_text_label": "Project Developmen...
# 4   ```json\n{\n  "visible_text_label": "Annex 6\n...
# 5   {\n  "visible_text_label": "Table C: Allocatio...
# 6   {\n  "visible_text_label": "Component",\n  "da...
# 7   ```json\n{\n  "visible_text_label": "none",\n ...
# 8   {\n  "visible_text_label": "Project Cost and F...
# 9   {\n  "visible_text_label": "Burundi at a glanc...
# 10  {\n  "visible_text_label": "Table 3: Procureme...
# 11  {\n  "visible_text_label": "Jordan STATEMENT O...
# 12  {\n  "visible_text_label": "Beneficiaries with...
# 13  {\n  "visible_text_label": "1 : FIGA is reform...
# 14  {\n  "visible_text_label": "STATEMENT OF IFC's...
# 15  ```json\n{\n  "visible_text_label": "1. Projec...
# 16  {\n  "visible_text_label": "TABLE A: PROJECT C...
# 17  {\n  "visible_text_label": "Enhanced productio...
# 18  {\n  "visible_text_label": "IDA Resources (US$...
# 19  ```json\n{\n  "visible_text_label": "Uganda ST...
# 20  ```json\n{\n  "visible_text_label": "Project F...
# 21  {\n  "visible_text_label": "Table C: Allocatio...
# 22  {\n  "visible_text_label": "Annex 4, Table D: ...
# 23  {\n  "visible_text_label": "Annex 4, Table C: ...
# 24  ```json\n{\n  "visible_text_label": "1. Projec...
# 25  {\n  "visible_text_label": "Category\nAmount o...
# 26  ```json\n{\n  "visible_text_label": "PRICES an...
# 27  ```json\n{\n  "visible_text_label": "4.7 موجز ...
# 28  ```json\n{\n  "visible_text_label": "Team",\n ...
# 29  {\n  "visible_text_label": "PDO Indicators by ...
# 30  {\n  "visible_text_label": "Tajikistan",\n  "d...
# 31  {\n  "visible_text_label": "Microcredentials f...
# 32  {\n  "visible_text_label": "JORDAN COMMUNITY I...
# 33  ```json\n{\n  "visible_text_label": "Table 5: ...
# 34  ```json\n{\n  "visible_text_label": "Table 1: ...
#
#                                                 usage  \
# 0   {'input_tokens': 26304, 'input_tokens_details'...
# 1   {'input_tokens': 37607, 'input_tokens_details'...
# 2   {'input_tokens': 37681, 'input_tokens_details'...
# 3   {'input_tokens': 49016, 'input_tokens_details'...
# 4   {'input_tokens': 37654, 'input_tokens_details'...
# 5   {'input_tokens': 26278, 'input_tokens_details'...
# 6   {'input_tokens': 48968, 'input_tokens_details'...
# 7   {'input_tokens': 26249, 'input_tokens_details'...
# 8   {'input_tokens': 37604, 'input_tokens_details'...
# 9   {'input_tokens': 37610, 'input_tokens_details'...
# 10  {'input_tokens': 48906, 'input_tokens_details'...
# 11  {'input_tokens': 37612, 'input_tokens_details'...
# 12  {'input_tokens': 26319, 'input_tokens_details'...
# 13  {'input_tokens': 26298, 'input_tokens_details'...
# 14  {'input_tokens': 37569, 'input_tokens_details'...
# 15  {'input_tokens': 26347, 'input_tokens_details'...
# 16  {'input_tokens': 26276, 'input_tokens_details'...
# 17  {'input_tokens': 49009, 'input_tokens_details'...
# 18  {'input_tokens': 37431, 'input_tokens_details'...
# 19  {'input_tokens': 26320, 'input_tokens_details'...
# 20  {'input_tokens': 26276, 'input_tokens_details'...
# 21  {'input_tokens': 48943, 'input_tokens_details'...
# 22  {'input_tokens': 37569, 'input_tokens_details'...
# 23  {'input_tokens': 37569, 'input_tokens_details'...
# 24  {'input_tokens': 26270, 'input_tokens_details'...
# 25  {'input_tokens': 37572, 'input_tokens_details'...
# 26  {'input_tokens': 26249, 'input_tokens_details'...
# 27  {'input_tokens': 48923, 'input_tokens_details'...
# 28  {'input_tokens': 48847, 'input_tokens_details'...
# 29  {'input_tokens': 37431, 'input_tokens_details'...
# 30  {'input_tokens': 37569, 'input_tokens_details'...
# 31  {'input_tokens': 26291, 'input_tokens_details'...
# 32  {'input_tokens': 37612, 'input_tokens_details'...
# 33  {'input_tokens': 48918, 'input_tokens_details'...
# 34  {'input_tokens': 37572, 'input_tokens_details'...
#
#                                                  cost  error
# 0   {'input_tokens': 26304, 'output_tokens': 121, ...    NaN
# 1   {'input_tokens': 37607, 'output_tokens': 142, ...    NaN
# 2   {'input_tokens': 37681, 'output_tokens': 162, ...    NaN
# 3   {'input_tokens': 49016, 'output_tokens': 118, ...    NaN
# 4   {'input_tokens': 37654, 'output_tokens': 141, ...    NaN
# 5   {'input_tokens': 26278, 'output_tokens': 111, ...    NaN
# 6   {'input_tokens': 48968, 'output_tokens': 116, ...    NaN
# 7   {'input_tokens': 26249, 'output_tokens': 117, ...    NaN
# 8   {'input_tokens': 37604, 'output_tokens': 114, ...    NaN
# 9   {'input_tokens': 37610, 'output_tokens': 140, ...    NaN
# 10  {'input_tokens': 48906, 'output_tokens': 125, ...    NaN
# 11  {'input_tokens': 37612, 'output_tokens': 149, ...    NaN
# 12  {'input_tokens': 26319, 'output_tokens': 128, ...    NaN
# 13  {'input_tokens': 26298, 'output_tokens': 180, ...    NaN
# 14  {'input_tokens': 37569, 'output_tokens': 150, ...    NaN
# 15  {'input_tokens': 26347, 'output_tokens': 154, ...    NaN
# 16  {'input_tokens': 26276, 'output_tokens': 127, ...    NaN
# 17  {'input_tokens': 49009, 'output_tokens': 108, ...    NaN
# 18  {'input_tokens': 37431, 'output_tokens': 121, ...    NaN
# 19  {'input_tokens': 26320, 'output_tokens': 148, ...    NaN
# 20  {'input_tokens': 26276, 'output_tokens': 115, ...    NaN
# 21  {'input_tokens': 48943, 'output_tokens': 117, ...    NaN
# 22  {'input_tokens': 37569, 'output_tokens': 125, ...    NaN
# 23  {'input_tokens': 37569, 'output_tokens': 118, ...    NaN
# 24  {'input_tokens': 26270, 'output_tokens': 141, ...    NaN
# 25  {'input_tokens': 37572, 'output_tokens': 136, ...    NaN
# 26  {'input_tokens': 26249, 'output_tokens': 135, ...    NaN
# 27  {'input_tokens': 48923, 'output_tokens': 138, ...    NaN
# 28  {'input_tokens': 48847, 'output_tokens': 111, ...    NaN
# 29  {'input_tokens': 37431, 'output_tokens': 111, ...    NaN
# 30  {'input_tokens': 37569, 'output_tokens': 122, ...    NaN
# 31  {'input_tokens': 26291, 'output_tokens': 166, ...    NaN
# 32  {'input_tokens': 37612, 'output_tokens': 133, ...    NaN
# 33  {'input_tokens': 48918, 'output_tokens': 117, ...    NaN
# 34  {'input_tokens': 37572, 'output_tokens': 127, ...    NaN

# %%
pd.json_normalize(df["cost"])["total_cost_usd"].sum()
# Out:
# np.float64(0.19334899999999997)

# %%
pd.json_normalize(df["llm_output"])
# Out:
#                                    visible_text_label  \
# 0   Consultancy Assignments with Selection Methods...
# 1   Figure 1: Countries, territories or areas with...
# 2   Annex 10: Country at a Glance\nWEST BANK AND G...
# 3            Project Development Objective Indicators
# 4   Annex 6\nEl Nino Emergency Road Repair Project...
# 5                Table C: Allocation of Loan Proceeds
# 6                                           Component
# 7                                                none
# 8                     Project Cost and Financing Plan
# 9                                 Burundi at a glance
# 10  Table 3: Procurement of major Goods and Works ...
# 11  Jordan STATEMENT OF IFC's Committed and Disbur...
# 12  Beneficiaries with access to basic services in...
# 13  1 : FIGA is reformed in a manner satisfactory ...
# 14  STATEMENT OF IFC's Committed and Disbursed Por...
# 15  1. Project components (see Annex 2 for a detai...
# 16  TABLE A: PROJECT COSTS BY PROCUREMENT ARRANGEM...
# 17  Enhanced production and income generation amon...
# 18                      IDA Resources (US$, Millions)
# 19  Uganda STATEMENT OF IFC's Committed and Disbur...
# 20                             Project Financing Data
# 21               Table C: Allocation of Loan Proceeds
# 22      Annex 4, Table D: Allocation of Loan Proceeds
# 23  Annex 4, Table C: Summary of Procurement Activ...
# 24  1. Project components (see Annex 2 for a detai...
# 25  Category\nAmount of the Grant Allocated (expre...
# 26                      PRICES and GOVERNMENT FINANCE
# 27              4.7 موجز التحليلي (بالدولار الأمريكي)
# 28                                               Team
# 29                     PDO Indicators by PDO Outcomes
# 30                                         Tajikistan
# 31  Microcredentials firm contracted\nMicrocredent...
# 32  JORDAN COMMUNITY INFRASTRUCTURE PROJECT LOCATI...
# 33                Table 5: Project Cost and Financing
# 34              Table 1: Implementation Support Table
#
#                                      data_modality  \
# 0                            administrative counts
# 1                          geospatial distribution
# 2   key economic ratios and demographic indicators
# 3                           performance indicators
# 4                            administrative counts
# 5                             financial allocation
# 6                                budget allocation
# 7                            administrative counts
# 8                              financial reporting
# 9                                 statistical data
# 10                           administrative counts
# 11                           administrative counts
# 12                           monitoring indicators
# 13                           administrative counts
# 14                             financial reporting
# 15                           administrative counts
# 16                           administrative counts
# 17                                          counts
# 18                           financial allocations
# 19                             financial reporting
# 20                       project financing details
# 21                            financial allocation
# 22                           financial allocations
# 23                           administrative counts
# 24                                   cost analysis
# 25                           financial allocations
# 26                                statistical data
# 27                                     projections
# 28                           administrative counts
# 29                           monitoring indicators
# 30                           administrative counts
# 31                             progress indicators
# 32                           administrative counts
# 33                           administrative counts
# 34    resource allocation and operational planning
#
#                                          topic_domain  \
# 0                                   urban development
# 1                                              health
# 2   poverty and social conditions, economic develo...
# 3                                  refugee management
# 4                       infrastructure rehabilitation
# 5                          infrastructure development
# 6                               community development
# 7                               infrastructure repair
# 8                          infrastructure development
# 9                           socio-economic indicators
# 10                                          education
# 11                           infrastructure financing
# 12                                     basic services
# 13                                        livelihoods
# 14                                economic investment
# 15                    infrastructure, social services
# 16                                      project costs
# 17                                        livelihoods
# 18                                 funding mechanisms
# 19                           infrastructure financing
# 20           community development, social assistance
# 21        infrastructure and environmental protection
# 22                                          education
# 23                                          education
# 24             municipal environmental infrastructure
# 25                                          education
# 26                                          economics
# 27                                  economic analysis
# 28                                          education
# 29                                  social assistance
# 30                                          economics
# 31                                          education
# 32                                     infrastructure
# 33                                             health
# 34                                          education
#
#                                            population       geographic_scope  \
# 0                                             unclear     West Bank and Gaza
# 1                                             unclear                 global
# 2                                  general population     West Bank and Gaza
# 3                                            refugees               Pakistan
# 4                                             unclear                 Uganda
# 5                                             unclear                unclear
# 6                                             unclear                 Rwanda
# 7                                             unclear                Albania
# 8                                             unclear                Croatia
# 9                                             unclear                Burundi
# 10                                            unclear                Lebanon
# 11                                          companies                 Jordan
# 12                                      beneficiaries                unclear
# 13                                              MSMEs                Burundi
# 14                                          companies             Tajikistan
# 15  local government units (LGUs), local contracto...     West Bank and Gaza
# 16                                            unclear                Burundi
# 17                  farmers, including female farmers                unclear
# 18                                            unclear               Djibouti
# 19                                          companies                 Uganda
# 20                                            unclear                Burundi
# 21                                            unclear                Croatia
# 22                                            unclear             Tajikistan
# 23                                            unclear             Tajikistan
# 24                                            unclear                Croatia
# 25                                            unclear                Lebanon
# 26                                      country-level                Albania
# 27                                            unclear               Djibouti
# 28                                            unclear                unclear
# 29                                      beneficiaries                unclear
# 30                                            unclear          country-level
# 31                       secondary education students             Costa Rica
# 32                               squatter settlements  Greater Amman, Jordan
# 33                                            unclear                   Iraq
# 34                                            unclear                Lebanon
#
#                                       temporal_aspect  \
# 0                                             unclear
# 1                       specific date (24 March 2020)
# 2                                  single year (1997)
# 3                                             unclear
# 4                specific dates and planned timelines
# 5                                             unclear
# 6                                             unclear
# 7                                             unclear
# 8                                    multi-year trend
# 9   single year (1997) and historical data from 19...
# 10                          specific project duration
# 11                                        single date
# 12                                            unclear
# 13                                            unclear
# 14                                      specific date
# 15                                            unclear
# 16                                            unclear
# 17                                   multi-year trend
# 18                                   multi-year trend
# 19                                        single year
# 20                                   multi-year trend
# 21                                            unclear
# 22                                            unclear
# 23                                            unclear
# 24                                            unclear
# 25                                            unclear
# 26            multiple years (1977, 1987, 1997, 1998)
# 27                                   multi-year trend
# 28                                             annual
# 29                        baseline and closing period
# 30                                   multi-year trend
# 31                                            unclear
# 32                                            unclear
# 33                                            unclear
# 34  multi-year plan (first twelve months and 12-48...
#
#                                     measurement_units  \
# 0                                          USD ($000)
# 1                                              counts
# 2                   counts, percentages, USD billions
# 3                                 percentages, counts
# 4                  US dollars, months, specific dates
# 5                             US$ million, percentage
# 6                                         US$ million
# 7                       monetary values (in currency)
# 8                                         DEM million
# 9   various (millions, percentages, ratios, US dol...
# 10                                        USD, months
# 11                                    millions of USD
# 12                                             counts
# 13                                                USD
# 14                             millions of US dollars
# 15                    USD million (US$M), percentages
# 16                                 million US dollars
# 17                                             Number
# 18                                    millions of USD
# 19                                 US dollar millions
# 20                                         US dollars
# 21                                        US $million
# 22                                        US$ million
# 23                      monetary values (million USD)
# 24                                        million DEM
# 25                                    USD, percentage
# 26                          US$ millions, percentages
# 27                                   thousands of USD
# 28             number of staff weeks, number of trips
# 29                                             number
# 30                          US$ millions, percentages
# 31                               counts / percentages
# 32                               geographic locations
# 33                                        US$ million
# 34                                                US$
#
#                                     short_description
# 0   The table lists various consultancy assignment...
# 1   The figure displays a world map indicating cou...
# 2   The snapshot reports on various socio-economic...
# 3   The table outlines project development objecti...
# 4   The snapshot contains a project budget and sch...
# 5   The table reports the allocation of loan proce...
# 6   The table reports the budget allocation for va...
# 7   The table reports various road repair projects...
# 8   The snapshot presents data on project costs an...
# 9   The snapshot provides various socio-economic i...
# 10  The table reports on the procurement of major ...
# 11  The table reports on the committed and disburs...
# 12  The table reports the baseline and end target ...
# 13  The table reports on the reform status of FIGA...
# 14  The table reports the committed and disbursed ...
# 15  The table presents the indicative costs and fi...
# 16  The table reports the costs associated with va...
# 17  The table reports the number of farmers and fe...
# 18  This table reports financial allocations from ...
# 19  The table reports the committed and disbursed ...
# 20  The table presents financing details for the S...
# 21  The table details the allocation of loan proce...
# 22  The table presents the allocation of loan proc...
# 23  The table summarizes procurement thresholds fo...
# 24  The table reports the costs associated with di...
# 25  The table reports the amount allocated for var...
# 26  The snapshot presents economic indicators for ...
# 27  The table presents financial projections relat...
# 28  The table outlines various expertise needed fo...
# 29  This table reports on project beneficiaries, i...
# 30  The data reports on various economic indicator...
# 31  The table reports on milestones related to a m...
# 32  The snapshot depicts a map showing the locatio...
# 33  The table outlines the costs and financing sou...
# 34  The table outlines the timing, focus areas, sk...
