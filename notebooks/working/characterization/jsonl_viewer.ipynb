# %%
import pandas as pd

df = pd.read_json("data/results_prwp_prwp_batch1.jsonl", lines=True)
df
# Out:
#                        snapshot_id  \
# 0  document_11225119_table_001.png
# 1   document_437731_figure_000.png
# 2  document_6731296_figure_010.png
#
#                                          image_path source_label  \
# 0  data/prwp_batch1/document_11225119_table_001.png         PRWP
# 1   data/prwp_batch1/document_437731_figure_000.png         PRWP
# 2  data/prwp_batch1/document_6731296_figure_010.png         PRWP
#
#                                           llm_output  \
# 0  {'visible_text_label': 'Table 2: Revenue Impli...
# 1  {'visible_text_label': 'Figure 1: Duration Bet...
# 2  {'visible_text_label': 'Figure 11 - Adjustment...
#
#                                           raw_output  \
# 0  {\n  "visible_text_label": "Table 2: Revenue I...
# 1  {\n  "visible_text_label": "Figure 1: Duration...
# 2  {\n  "visible_text_label": "Figure 11 - Adjust...
#
#                                                usage  \
# 0  {'input_tokens': 26307, 'input_tokens_details'...
# ...

# %%
max([x["total_cost_usd"] for x in df["cost"]]) * 60 * 300
# Out:
# 103.19399999999999
